# %%
import pandas as pd
import numpy as np

df= pd.read_csv('../DATA/cancer_classification.csv')
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.isna().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# benign_0__mal_1            0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X= df.drop('benign_0__mal_1', axis=1)
y=df['benign_0__mal_1']
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)

# %%
pwd
# Out:
# 'c:\\data science practice\\python practice\\5.Deep Learning\\5.tensorboard'

# %%
from datetime import datetime
loc="c:\\data science practice\\python practice\\5.Deep Learning\\5.tensorboard"
loc
# Out:
# 'c:\\data science practice\\python practice\\5.Deep Learning\\5.tensorboard'

# %%
from keras.callbacks import TensorBoard
board = TensorBoard(log_dir=loc,histogram_freq=1,write_graph=True, write_images=True,update_freq='epoch',embeddings_freq=1,profile_batch=2)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

from keras.callbacks import EarlyStopping

early_stop= EarlyStopping(monitor='val_loss', patience=25, mode='min')

model = Sequential()
model.add(Dense(31, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(13, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=600, callbacks=[early_stop,board], validation_data=(X_train, y_train))
# Out:
# Epoch 1/600
# 13/13 [==============================] - 3s 84ms/step - loss: 0.7000 - accuracy: 0.5578 - val_loss: 0.6808 - val_accuracy: 0.6960
# Epoch 2/600
# 13/13 [==============================] - 1s 43ms/step - loss: 0.6846 - accuracy: 0.6206 - val_loss: 0.6566 - val_accuracy: 0.7714
# Epoch 3/600
# 13/13 [==============================] - 0s 29ms/step - loss: 0.6825 - accuracy: 0.5955 - val_loss: 0.6342 - val_accuracy: 0.8116
# Epoch 4/600
# 13/13 [==============================] - 0s 31ms/step - loss: 0.6519 - accuracy: 0.6457 - val_loss: 0.6165 - val_accuracy: 0.8367
# Epoch 5/600
# 13/13 [==============================] - 0s 36ms/step - loss: 0.6355 - accuracy: 0.6809 - val_loss: 0.5998 - val_accuracy: 0.8417
# Epoch 6/600
# 13/13 [==============================] - 0s 36ms/step - loss: 0.6242 - accuracy: 0.6809 - val_loss: 0.5763 - val_accuracy: 0.8719
# Epoch 7/600
# ...
